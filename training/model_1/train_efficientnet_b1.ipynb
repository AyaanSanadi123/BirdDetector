# %%
# --- STEP 1: Imports & Configuration ---
import matplotlib.pyplot as plt
import numpy as np
import os
import tensorflow as tf
import json
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential

# --- Paths ---
# Path to your massive, unified dataset
DATA_DIR = r"D:\BirdDetector\training\model_1\Data\data_final"
# Filenames for saving our output
MODEL_SAVE_PATH = "efficientnet_b1_bird_model.keras"
CLASS_NAMES_SAVE_PATH = "class_names.json"

# --- Model Parameters (Adjusted for B1) ---
# EfficientNetV2-B1 is optimized for 240x240 input images.
IMG_SIZE = (240, 240)

# Since B1 is larger, we reduce the batch size to 16 to prevent
# running out of GPU memory (OOM errors).
BATCH_SIZE = 16

# We'll set a high maximum, but Early Stopping will likely end it sooner.
EPOCHS = 25

# --- GPU Check ---
print(f"TensorFlow Version: {tf.__version__}")
gpus = tf.config.list_physical_devices('GPU')
print(f"Num GPUs Available: {len(gpus)}")
if len(gpus) > 0:
    print("✅ Success! A GPU is detected and will be used for training.")
else:
    print("❌ Warning: No GPU detected. Training will be extremely slow.")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 5
#       3 import numpy as np
#       4 import os
# ----> 5 import tensorflow as tf
#       6 import json
#       7 from tensorflow import keras
#
# ModuleNotFoundError: No module named 'tensorflow'
